# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot,pylab as plt

# %%
df=pd.read_csv("Kern_County.csv")
df
# Out:
#      CDIAC Number                                            Issuer  \
# 0       2022-1204                          Richland School District
# 1       1996-1769  Delano Joint Union High School District (CSCRPA)
# 2       2022-1205                          Richland School District
# 3       2015-1538                                       Bakersfield
# 4       2001-0720           Kern County Board of Education (CSCRPA)
# ...           ...                                               ...
# 1195    2008-1301                    Mojave Unified School District
# 1196    1994-1262                         Kern High School District
# 1197    1988-0037                                       Bakersfield
# 1198    2003-0562             North of River Sanitary District No 1
# 1199    2007-0941                         Beardsley School District
#
#                                      Issuance Documents Sold Status  \
# 0     2022-1204.pdf (http://cdiacdocs.sto.ca.gov/202...        SOLD
# 1     Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 2     2022-1205.pdf (http://cdiacdocs.sto.ca.gov/202...        SOLD
# 3     2015-1538.pdf (http://cdiacdocs.sto.ca.gov/201...        SOLD
# 4     Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# ...                                                 ...         ...
# 1195  2008-1301.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
# 1196  Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 1197  Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 1198  2003-0562.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
# 1199  2007-0941.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
#
#                    Sale Date  \
# 0     07/14/2022 12:00:00 AM
# 1     12/11/1996 12:00:00 AM
# 2     07/14/2022 12:00:00 AM
# 3     06/10/2015 12:00:00 AM
# 4     06/21/2001 12:00:00 AM
# ...                      ...
# 1195  01/15/2009 12:00:00 AM
# 1196  07/28/1994 12:00:00 AM
# 1197  04/19/1988 12:00:00 AM
# 1198  05/15/2003 12:00:00 AM
# 1199  07/18/2007 12:00:00 AM
#
#                                             ADTR Report  \
# 0     2022-1204 Report (https://debtwatch.treasurer....
# 1     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 2     2022-1205 Report (https://debtwatch.treasurer....
# 3     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 4     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# ...                                                 ...
# 1195  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1196  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1197  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1198  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1199  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
#
#                                      ADTR Filing Status ADTR Reportable  \
# 0     PENDING (http://cdiacdocs.sto.ca.gov/ADTRFilin...               Y
# 1     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 2     PENDING (http://cdiacdocs.sto.ca.gov/ADTRFilin...               Y
# 3     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 4     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# ...                                                 ...             ...
# 1195  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1196  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1197  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1198  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1199  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
#
#      ADTR Reportable Next Fiscal Year ADTR Last Reported Year  ...  \
# 0                                 Yes                     NaN  ...
# 1                                 NaN                     NaN  ...
# 2                                 Yes                     NaN  ...
# 3                                 NaN                     NaN  ...
# 4                                 NaN                     NaN  ...
# ...                               ...                     ...  ...
# 1195                              NaN                     NaN  ...
# 1196                              NaN                     NaN  ...
# 1197                              NaN                     NaN  ...
# 1198                              NaN                     NaN  ...
# 1199                              NaN                     NaN  ...
#
#      Placement Agent Fee Financial Advisor Fee Bond Counsel Fee  \
# 0                45000.0              50000.00         40500.00
# 1                    0.0                  0.00             0.00
# 2                25000.0              40000.00         40500.00
# 3                    0.0               4427.72          9740.97
# 4                    NaN                   NaN              NaN
# ...                  ...                   ...              ...
# 1195                 0.0              77451.35         29000.00
# 1196                 0.0                  0.00             0.00
# 1197                 NaN                   NaN              NaN
# 1198                 NaN                   NaN              NaN
# 1199                 0.0              75000.00         34558.00
#
#      Co-Bond Counsel Fee Disclosure Counsel Fee Borrower Counsel Fee  \
# 0                    NaN                    NaN                  NaN
# 1                    0.0                   0.00                  0.0
# 2                    NaN                    NaN                  NaN
# 3                    0.0                4617.46                  0.0
# 4                    NaN                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1195                 0.0               25000.00                  0.0
# 1196                 0.0                   0.00                  0.0
# 1197                 NaN                    NaN                  NaN
# 1198                 NaN                    NaN                  NaN
# 1199                 0.0               10000.00                  0.0
#
#      Trustee Fee Credit Enhancement Fee  Rating Agency Fee  \
# 0        5018.49                   0.00                NaN
# 1           0.00                   0.00                0.0
# 2        3951.37                   0.00                NaN
# 3           0.00                   0.00                0.0
# 4            NaN                    NaN                NaN
# ...          ...                    ...                ...
# 1195     1500.00               41970.52             5900.0
# 1196        0.00                   0.00                0.0
# 1197         NaN                    NaN                NaN
# 1198         NaN                    NaN                NaN
# 1199     1270.00               21222.00             5400.0
#
#       Other Issuance Expenses
# 0                    19481.51
# 1                        0.00
# 2                    15548.63
# 3                    11057.76
# 4                         NaN
# ...                       ...
# 1195                 36089.09
# 1196                     0.00
# 1197                      NaN
# 1198                      NaN
# 1199                 14272.00
#
# [1200 rows x 69 columns]

# %%
df.shape
# Out:
# (1200, 69)

# %%
df.size
# Out:
# 82800

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      CDIAC Number                                            Issuer  \
# 0       2022-1204                          Richland School District
# 1       1996-1769  Delano Joint Union High School District (CSCRPA)
# 2       2022-1205                          Richland School District
# 3       2015-1538                                       Bakersfield
# 4       2001-0720           Kern County Board of Education (CSCRPA)
# ...           ...                                               ...
# 1195    2008-1301                    Mojave Unified School District
# 1196    1994-1262                         Kern High School District
# 1197    1988-0037                                       Bakersfield
# 1198    2003-0562             North of River Sanitary District No 1
# 1199    2007-0941                         Beardsley School District
#
#                                      Issuance Documents Sold Status  \
# 0     2022-1204.pdf (http://cdiacdocs.sto.ca.gov/202...        SOLD
# 1     Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 2     2022-1205.pdf (http://cdiacdocs.sto.ca.gov/202...        SOLD
# 3     2015-1538.pdf (http://cdiacdocs.sto.ca.gov/201...        SOLD
# 4     Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# ...                                                 ...         ...
# 1195  2008-1301.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
# 1196  Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 1197  Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 1198  2003-0562.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
# 1199  2007-0941.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
#
#                    Sale Date  \
# 0     07/14/2022 12:00:00 AM
# 1     12/11/1996 12:00:00 AM
# 2     07/14/2022 12:00:00 AM
# 3     06/10/2015 12:00:00 AM
# 4     06/21/2001 12:00:00 AM
# ...                      ...
# 1195  01/15/2009 12:00:00 AM
# 1196  07/28/1994 12:00:00 AM
# 1197  04/19/1988 12:00:00 AM
# 1198  05/15/2003 12:00:00 AM
# 1199  07/18/2007 12:00:00 AM
#
#                                             ADTR Report  \
# 0     2022-1204 Report (https://debtwatch.treasurer....
# 1     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 2     2022-1205 Report (https://debtwatch.treasurer....
# 3     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 4     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# ...                                                 ...
# 1195  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1196  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1197  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1198  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1199  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
#
#                                      ADTR Filing Status ADTR Reportable  \
# 0     PENDING (http://cdiacdocs.sto.ca.gov/ADTRFilin...               Y
# 1     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 2     PENDING (http://cdiacdocs.sto.ca.gov/ADTRFilin...               Y
# 3     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 4     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# ...                                                 ...             ...
# 1195  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1196  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1197  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1198  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1199  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
#
#      ADTR Reportable Next Fiscal Year ADTR Last Reported Year  ...  \
# 0                                 Yes                     NaN  ...
# 1                                 NaN                     NaN  ...
# 2                                 Yes                     NaN  ...
# 3                                 NaN                     NaN  ...
# 4                                 NaN                     NaN  ...
# ...                               ...                     ...  ...
# 1195                              NaN                     NaN  ...
# 1196                              NaN                     NaN  ...
# 1197                              NaN                     NaN  ...
# 1198                              NaN                     NaN  ...
# 1199                              NaN                     NaN  ...
#
#      Placement Agent Fee Financial Advisor Fee Bond Counsel Fee  \
# 0                45000.0              50000.00         40500.00
# 1                    0.0                  0.00             0.00
# 2                25000.0              40000.00         40500.00
# 3                    0.0               4427.72          9740.97
# 4                    NaN                   NaN              NaN
# ...                  ...                   ...              ...
# 1195                 0.0              77451.35         29000.00
# 1196                 0.0                  0.00             0.00
# 1197                 NaN                   NaN              NaN
# 1198                 NaN                   NaN              NaN
# 1199                 0.0              75000.00         34558.00
#
#      Co-Bond Counsel Fee Disclosure Counsel Fee Borrower Counsel Fee  \
# 0                    NaN                    NaN                  NaN
# 1                    0.0                   0.00                  0.0
# 2                    NaN                    NaN                  NaN
# 3                    0.0                4617.46                  0.0
# 4                    NaN                    NaN                  NaN
# ...                  ...                    ...                  ...
# 1195                 0.0               25000.00                  0.0
# 1196                 0.0                   0.00                  0.0
# 1197                 NaN                    NaN                  NaN
# 1198                 NaN                    NaN                  NaN
# 1199                 0.0               10000.00                  0.0
#
#      Trustee Fee Credit Enhancement Fee  Rating Agency Fee  \
# 0        5018.49                   0.00                NaN
# 1           0.00                   0.00                0.0
# 2        3951.37                   0.00                NaN
# 3           0.00                   0.00                0.0
# 4            NaN                    NaN                NaN
# ...          ...                    ...                ...
# 1195     1500.00               41970.52             5900.0
# 1196        0.00                   0.00                0.0
# 1197         NaN                    NaN                NaN
# 1198         NaN                    NaN                NaN
# 1199     1270.00               21222.00             5400.0
#
#       Other Issuance Expenses
# 0                    19481.51
# 1                        0.00
# 2                    15548.63
# 3                    11057.76
# 4                         NaN
# ...                       ...
# 1195                 36089.09
# 1196                     0.00
# 1197                      NaN
# 1198                      NaN
# 1199                 14272.00
#
# [1200 rows x 69 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 69 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CDIAC Number                       1200 non-null   object
#  1   Issuer                             1200 non-null   object
#  2   Issuance Documents                 1200 non-null   object
#  3   Sold Status                        1200 non-null   object
#  4   Sale Date                          1200 non-null   object
#  5   ADTR Report                        1200 non-null   object
#  6   ADTR Filing Status                 1200 non-null   object
#  7   ADTR Reportable                    1200 non-null   object
#  8   ADTR Reportable Next Fiscal Year   151 non-null    object
#  9   ADTR Last Reported Year            117 non-null    object
#  10  Debt Policy                        158 non-null    object
#  11  Issuer County                      1200 non-null   object
#  12  MKR Authority                      1200 non-null   object
#  13  Local Obligation                   1200 non-null   object
#  14  MKR CDIAC Number                   8 non-null      object
#  15  Issuer Group                       1200 non-null   object
#  16  Issuer Type                        1200 non-null   object
#  17  Project Name                       1012 non-null   object
#  18  Principal Amount                   1200 non-null   float64
#  19  New Money                          1200 non-null   float64
#  20  Refunding Amount                   1081 non-null   float64
#  21  Net Issue Discount/Premium         919 non-null    float64
#  22  Environmental/Social Impact Bonds  1191 non-null   object
#  23  Debt Type                          1200 non-null   object
#  24  Purpose                            1198 non-null   object
#  25  Source of Repayment                1199 non-null   object
#  26  TIC Interest Rate                  559 non-null    float64
#  27  NIC Interest Rate                  847 non-null    float64
#  28  Interest Type                      915 non-null    object
#  29  Other Interest Type                6 non-null      object
#  30  Federally Taxable                  1200 non-null   object
#  31  First Optional Call Date           480 non-null    object
#  32  Final Maturity Date                1057 non-null   object
#  33  CAB Flag                           750 non-null    object
#  34  S and P Rating                     1198 non-null   object
#  35  Moody Rating                       1198 non-null   object
#  36  Fitch Rating                       1198 non-null   object
#  37  Other Rating                       1198 non-null   object
#  38  Guarantor Flag                     579 non-null    object
#  39  Guarantor                          513 non-null    object
#  40  Sale Type (Comp/Neg)               1200 non-null   object
#  41  Private Placement Flag             1200 non-null   object
#  42  Underwriter                        1024 non-null   object
#  43  Lender                             0 non-null      float64
#  44  Purchaser                          123 non-null    object
#  45  Placement Agent                    52 non-null     object
#  46  Financial Advisor                  657 non-null    object
#  47  Co-Financial Advisor               0 non-null      float64
#  48  Bond Counsel                       1189 non-null   object
#  49  Co-Bond Counsel                    0 non-null      float64
#  50  Disclosure Counsel                 227 non-null    object
#  51  Borrower Counsel                   2 non-null      object
#  52  Trustee                            814 non-null    object
#  53  Issue Costs Pct of Principal Amt   1198 non-null   float64
#  54  Total Issuance Costs               1198 non-null   float64
#  55  UW Takedown                        601 non-null    float64
#  56  UW Mngmt Fee                       599 non-null    float64
#  57  UW Expenses                        893 non-null    float64
#  58  UW Total Discount/Spread           1198 non-null   float64
#  59  Placement Agent Fee                598 non-null    float64
#  60  Financial Advisor Fee              665 non-null    float64
#  61  Bond Counsel Fee                   728 non-null    float64
#  62  Co-Bond Counsel Fee                595 non-null    float64
#  63  Disclosure Counsel Fee             649 non-null    float64
#  64  Borrower Counsel Fee               583 non-null    float64
#  65  Trustee Fee                        682 non-null    float64
#  66  Credit Enhancement Fee             639 non-null    float64
#  67  Rating Agency Fee                  684 non-null    float64
#  68  Other Issuance Expenses            725 non-null    float64
# dtypes: float64(25), object(44)
# memory usage: 647.0+ KB

# %%
df.nunique()
# Out:
# CDIAC Number               1200
# Issuer                      178
# Issuance Documents          689
# Sold Status                   2
# Sale Date                   833
#                            ...
# Borrower Counsel Fee          6
# Trustee Fee                 210
# Credit Enhancement Fee      250
# Rating Agency Fee           190
# Other Issuance Expenses     493
# Length: 69, dtype: int64

# %%
df.isnull().sum()
# Out:
# CDIAC Number                 0
# Issuer                       0
# Issuance Documents           0
# Sold Status                  0
# Sale Date                    0
#                           ...
# Borrower Counsel Fee       617
# Trustee Fee                518
# Credit Enhancement Fee     561
# Rating Agency Fee          516
# Other Issuance Expenses    475
# Length: 69, dtype: int64

# %%
mode= df["ADTR Reportable Next Fiscal Year"].mode().values[0]
df["ADTR Reportable Next Fiscal Year"]=df["ADTR Reportable Next Fiscal Year"].fillna(mode)

# %%
mode= df["ADTR Last Reported Year"].mode().values[0]
df["ADTR Last Reported Year"]=df["ADTR Last Reported Year"].fillna(mode)

# %%
mode= df["Debt Policy"].mode().values[0]
df["Debt Policy"]=df["Debt Policy"].fillna(mode)

# %%
mode= df["MKR CDIAC Number"].mode().values[0]
df["MKR CDIAC Number"]=df["MKR CDIAC Number"].fillna(mode)

# %%
mode= df["Project Name"].mode().values[0]
df["Project Name"]=df["Project Name"].fillna(mode)

# %%
mean= df["Refunding Amount"].mean()
df["Refunding Amount"]=df["Refunding Amount"].fillna(mean)

# %%
mean= df["Net Issue Discount/Premium"].mean()
df["Net Issue Discount/Premium"]=df["Net Issue Discount/Premium"].fillna(mean)

# %%
mode= df["Environmental/Social Impact Bonds"].mode().values[0]
df["Environmental/Social Impact Bonds"]=df["Environmental/Social Impact Bonds"].fillna(mode)

# %%
mode= df["Purpose"].mode().values[0]
df["Purpose"]=df["Purpose"].fillna(mode)

# %%
mode= df["Source of Repayment"].mode().values[0]
df["Source of Repayment"]=df["Source of Repayment"].fillna(mode)

# %%
mean= df["TIC Interest Rate"].mean()
df["TIC Interest Rate"]=df["TIC Interest Rate"].fillna(mean)

# %%
mean= df["NIC Interest Rate"].mean()
df["NIC Interest Rate"]=df["NIC Interest Rate"].fillna(mean)

# %%
mode= df["Interest Type"].mode().values[0]
df["Interest Type"]=df["Interest Type"].fillna(mode)

# %%
mode= df["Other Interest Type"].mode().values[0]
df["Other Interest Type"]=df["Other Interest Type"].fillna(mode)

# %%
mode= df["First Optional Call Date"].mode().values[0]
df["First Optional Call Date"]=df["First Optional Call Date"].fillna(mode)

# %%
mode= df["Final Maturity Date"].mode().values[0]
df["Final Maturity Date"]=df["Final Maturity Date"].fillna(mode)

# %%
mode= df["CAB Flag"].mode().values[0]
df["CAB Flag"]=df["CAB Flag"].fillna(mode)

# %%
mode= df["S and P Rating"].mode().values[0]
df["S and P Rating"]=df["S and P Rating"].fillna(mode)

# %%
mode= df["Moody Rating"].mode().values[0]
df["Moody Rating"]=df["Moody Rating"].fillna(mode)

# %%
mode= df["Fitch Rating"].mode().values[0]
df["Fitch Rating"]=df["Fitch Rating"].fillna(mode)

# %%
mode= df["Other Rating"].mode().values[0]
df["Other Rating"]=df["Other Rating"].fillna(mode)

# %%
mode= df["Guarantor Flag"].mode().values[0]
df["Guarantor Flag"]=df["Guarantor Flag"].fillna(mode)

# %%
mode= df["Guarantor"].mode().values[0]
df["Guarantor"]=df["Guarantor"].fillna(mode)

# %%
mode= df["Underwriter"].mode().values[0]
df["Underwriter"]=df["Underwriter"].fillna(mode)

# %%
mean= df["Lender"].mean()
df["Lender"]=df["Lender"].fillna(mean)

# %%
mode= df["Purchaser"].mode().values[0]
df["Purchaser"]=df["Purchaser"].fillna(mode)

# %%
mode= df["Placement Agent"].mode().values[0]
df["Placement Agent"]=df["Placement Agent"].fillna(mode)

# %%
mode= df["Financial Advisor"].mode().values[0]
df["Financial Advisor"]=df["Financial Advisor"].fillna(mode)

# %%
mean= df["Co-Financial Advisor"].mean()
df["Co-Financial Advisor"]=df["Co-Financial Advisor"].fillna(mean)

# %%
mode = df["Bond Counsel"].mode().values[0]
df["Bond Counsel"]=df["Bond Counsel"].fillna(mode)

# %%
mode = df["Disclosure Counsel"].mode().values[0]
df["Disclosure Counsel"]=df["Disclosure Counsel"].fillna(mode)

# %%
mode = df["Trustee"].mode().values[0]
df["Trustee"]=df["Trustee"].fillna(mode)

# %%
mean= df["Issue Costs Pct of Principal Amt"].mean()
df["Issue Costs Pct of Principal Amt"]=df["Issue Costs Pct of Principal Amt"].fillna(mean)

# %%
mean= df["Total Issuance Costs"].mean()
df["Total Issuance Costs"]=df["Total Issuance Costs"].fillna(mean)

# %%
df.isnull().sum()
# Out:
# CDIAC Number                 0
# Issuer                       0
# Issuance Documents           0
# Sold Status                  0
# Sale Date                    0
#                           ...
# Borrower Counsel Fee       617
# Trustee Fee                518
# Credit Enhancement Fee     561
# Rating Agency Fee          516
# Other Issuance Expenses    475
# Length: 69, dtype: int64

# %%
df.drop(columns=["CDIAC Number","Issuer","MKR CDIAC Number","Fitch Rating","Other Rating","Lender","Co-Financial Advisor","Co-Bond Counsel","Borrower Counsel","Issuer County","TIC Interest Rate","NIC Interest Rate","Net Issue Discount/Premium","Sale Date","Project Name","Trustee","ADTR Reportable Next Fiscal Year"],inplace=True)

# %%
df
# Out:
#                                      Issuance Documents Sold Status  \
# 0     2022-1204.pdf (http://cdiacdocs.sto.ca.gov/202...        SOLD
# 1     Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 2     2022-1205.pdf (http://cdiacdocs.sto.ca.gov/202...        SOLD
# 3     2015-1538.pdf (http://cdiacdocs.sto.ca.gov/201...        SOLD
# 4     Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# ...                                                 ...         ...
# 1195  2008-1301.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
# 1196  Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 1197  Pending (http://cdiacdocs.sto.ca.gov/Pending.pdf)        SOLD
# 1198  2003-0562.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
# 1199  2007-0941.pdf (http://cdiacdocs.sto.ca.gov/200...        SOLD
#
#                                             ADTR Report  \
# 0     2022-1204 Report (https://debtwatch.treasurer....
# 1     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 2     2022-1205 Report (https://debtwatch.treasurer....
# 3     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 4     No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# ...                                                 ...
# 1195  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1196  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1197  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1198  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
# 1199  No Report (http://cdiacdocs.sto.ca.gov/NoRepor...
#
#                                      ADTR Filing Status ADTR Reportable  \
# 0     PENDING (http://cdiacdocs.sto.ca.gov/ADTRFilin...               Y
# 1     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 2     PENDING (http://cdiacdocs.sto.ca.gov/ADTRFilin...               Y
# 3     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 4     N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# ...                                                 ...             ...
# 1195  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1196  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1197  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1198  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
# 1199  N/A (http://cdiacdocs.sto.ca.gov/ADTRFilingSta...               N
#
#      ADTR Last Reported Year Debt Policy MKR Authority Local Obligation  \
# 0     06/30/2022 12:00:00 AM           Y            NO               NO
# 1     06/30/2022 12:00:00 AM           Y            NO               NO
# 2     06/30/2022 12:00:00 AM           Y            NO               NO
# 3     06/30/2022 12:00:00 AM           Y            NO               NO
# 4     06/30/2022 12:00:00 AM           Y            NO               NO
# ...                      ...         ...           ...              ...
# 1195  06/30/2022 12:00:00 AM           Y            NO               NO
# 1196  06/30/2022 12:00:00 AM           Y            NO               NO
# 1197  06/30/2022 12:00:00 AM           Y            NO               NO
# 1198  06/30/2022 12:00:00 AM           Y            NO               NO
# 1199  06/30/2022 12:00:00 AM           Y            NO               NO
#
#            Issuer Group  ... Placement Agent Fee  Financial Advisor Fee  \
# 0          K-14 Schools  ...             45000.0               50000.00
# 1          K-14 Schools  ...                 0.0                   0.00
# 2          K-14 Schools  ...             25000.0               40000.00
# 3                Cities  ...                 0.0                4427.72
# 4              Counties  ...                 NaN                    NaN
# ...                 ...  ...                 ...                    ...
# 1195       K-14 Schools  ...                 0.0               77451.35
# 1196       K-14 Schools  ...                 0.0                   0.00
# 1197             Cities  ...                 NaN                    NaN
# 1198  Special Districts  ...                 NaN                    NaN
# 1199       K-14 Schools  ...                 0.0               75000.00
#
#       Bond Counsel Fee  Co-Bond Counsel Fee Disclosure Counsel Fee  \
# 0             40500.00                  NaN                    NaN
# 1                 0.00                  0.0                   0.00
# 2             40500.00                  NaN                    NaN
# 3              9740.97                  0.0                4617.46
# 4                  NaN                  NaN                    NaN
# ...                ...                  ...                    ...
# 1195          29000.00                  0.0               25000.00
# 1196              0.00                  0.0                   0.00
# 1197               NaN                  NaN                    NaN
# 1198               NaN                  NaN                    NaN
# 1199          34558.00                  0.0               10000.00
#
#      Borrower Counsel Fee Trustee Fee Credit Enhancement Fee  \
# 0                     NaN     5018.49                   0.00
# 1                     0.0        0.00                   0.00
# 2                     NaN     3951.37                   0.00
# 3                     0.0        0.00                   0.00
# 4                     NaN         NaN                    NaN
# ...                   ...         ...                    ...
# 1195                  0.0     1500.00               41970.52
# 1196                  0.0        0.00                   0.00
# 1197                  NaN         NaN                    NaN
# 1198                  NaN         NaN                    NaN
# 1199                  0.0     1270.00               21222.00
#
#      Rating Agency Fee Other Issuance Expenses
# 0                  NaN                19481.51
# 1                  0.0                    0.00
# 2                  NaN                15548.63
# 3                  0.0                11057.76
# 4                  NaN                     NaN
# ...                ...                     ...
# 1195            5900.0                36089.09
# 1196               0.0                    0.00
# 1197               NaN                     NaN
# 1198               NaN                     NaN
# 1199            5400.0                14272.00
#
# [1200 rows x 52 columns]

# %%
df.shape
# Out:
# (1200, 52)
